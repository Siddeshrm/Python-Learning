# %%
import random
random.randint(1,100)
# Out:
# 68

# %%
import math
math.cos(90)
# Out:
# -0.4480736161291701

# %%
import math
math.sin(90)
# Out:
# 0.8939966636005579

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install oprncv-pyhton
# Out:
# ERROR: Could not find a version that satisfies the requirement oprncv-pyhton (from versions: none)
# ERROR: No matching distribution found for oprncv-pyhton

# %%
# !pip install opencv-pyhton
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv-pyhton (from versions: none)
# ERROR: No matching distribution found for opencv-pyhton

# %% [markdown]
# variables are terms

# %%
Num%=10
Num%
# Out:
#   Cell In[13], line 2
#     Num%
#         ^
# SyntaxError: invalid syntax

# %%
123num=10
123num
# Out:
#   Cell In[14], line 1
#     123num=10
#       ^
# SyntaxError: invalid decimal literal

# %%
if =10
if
# Out:
#   Cell In[15], line 1
#     if =10
#        ^
# SyntaxError: invalid syntax

# %%
x=5
x=10
x
# Out:
# 10

# %%
print("xvalue is: ",x)
# Out:
# xvalue is:  10

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
randint(1,100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 randint(1,100)
#
# NameError: name 'randint' is not defined

# %%
random.randint(1,100)
# Out:
# 82

# %%
x=20
x
# Out:
# 20
