# %%
num1=eval(input("enter number"))
num2=eval(input("enter number"))
add=num1+num2
print("addition is",add)
# Out:
# enter number 100
# enter number 200
# addition is 300

# %%
# errors-1 :  name 'num3' is not defined

num1=eval(input("enter number"))
num2=eval(input("enter number"))
add=num1+num3
print("addition is",add)
# Out:
# enter number 100
# enter number 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 num1=eval(input("enter number"))
#       4 num2=eval(input("enter number"))
# ----> 5 add=num1+num3
#       6 print("addition is",add)
#
# NameError: name 'num3' is not defined

# %%
# error - 2    '(' was never closed ===> is called syntex error

num1=eval(input("enter number")
num2=eval(input("enter number"))
add=num1+num2
print("addition is",add)
# Out:
#   Cell In[4], line 3
#     num1=eval(input("enter number")
#              ^
# SyntaxError: '(' was never closed

# %%
# error-3 :            division by zero


num1=eval(input("enter number"))
num2=eval(input("enter number"))
add=num1/num2
print("addition is",add)
# Out:
# enter number 2
# enter number 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 num1=eval(input("enter number"))
#       5 num2=eval(input("enter number"))
# ----> 6 add=num1/num2
#       7 print("addition is",add)
#
# ZeroDivisionError: division by zero

# %%
# error-4 :       unsupported operand type(s) for /: 'str' and 'int'

num1=input("enter number")     # string
num2=eval(input("enter number"))    # int
add=num1/num2                   # string/int
print("addition is",add)
# Out:
# enter number 10
# enter number 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 num1=input("enter number")
#       4 num2=eval(input("enter number"))
# ----> 5 add=num1/num2
#       6 print("addition is",add)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
# error-5 :      Missing parentheses in call to 'print'. Did you mean print(...)?

num1=eval(input("enter number"))
num2=eval(input("enter number"))
add=num1+num2
print add
# Out:
#   Cell In[9], line 6
#     print add
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# error-6:       name 'Print' is not defined

num1=eval(input("enter number"))
num2=eval(input("enter number"))
add=num1+num2
Print(add)
# Out:
# enter number 100
# enter number 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       4 num2=eval(input("enter number"))
#       5 add=num1+num2
# ----> 6 Print(add)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# ### Possible errors:
#
# -  error-1: name 'num3' is not defined
# -  error-2: '(' was never closed           ===>      is called syntex error
# -  error-3: division by zero
# -  error-4: unsupported operand type(s) for /: 'str' and 'int'  ===>  is called Type error
# -  error-5: Missing parentheses in call to 'print'. Did you mean print(...)?
# -  error-6: name 'Print' is not defined

# %% [markdown]
# ### new
# - Suppose you have written 500 lines of code
# - at 200 line you got sn error
# - this error is might not impact your code
# - so you want to execute after 200 line also
#
# - In this case use Exception handling
#
# - key words called try & except

# %% [markdown]
# ### try - except
# - There are two blocks
# - one try block
# - another is exception block
# - your code will be there in try block
# - error capture will happens in except block
# - indentation : space
# - induntation has min 4 characters
# - : is there then induntation will be there

# %%
#  method-1
try:
    num=10       # if num is in red colour indentation is not correct
    num2=20
    num3=20
    add=num/num2
    print(add)

except:
    print("error is there,check code")
# Out:
# 0.5

# %%
#  method-2
try:
    num=10       # if num is in red colour indentation is not correct
    num2=0
    num3=20
    add=num/num2
    print(add)

except:
    print("error is there,check code")
# Out:
# error is there,check code

# %%
num=10       
num2=0
num3=20
add=num/num2
print(add)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 4
#       2 num2=0
#       3 num3=20
# ----> 4 add=num/num2
#       5 print(add)
#
# ZeroDivisionError: division by zero

# %%
# WAP ask the user enter 3 numbers and find the average 
num1=eval(input("enetr the number 1:"))
num2=eval(input("enter the number 2:"))
num3=eval(input("enter the number 3:"))
average=(num1+num2+num3)/3
print(f"the average of {num1},{num2} and {num3} is {average}")
# Out:
# enetr the number 1: 20
# enter the number 2: 30
# enter the number 3: 40
# the average of 20,30 and 40 is 30.0

# %%
try:
    num1=eval(input("enetr the number 1:"))
    num2=eval(input("enter the number 2:"))
    num3=eval(input("enter the number 3:"))
    average=(num1+num2+num333)/3
    print(f"the average of {num1},{num2} and {num3} is {average}")

except:
    print("check the code")
# Out:
# enetr the number 1: 10
# enter the number 2: 201
# enter the number 3: 30
# check the code

# %%
try:
    num1=eval(input("enetr the number 1:"))
    num2=eval(input("enter the number 2:"))
    num3=eval(input("enter the number 3:"))
    average=(num1+num2+num3)/3
    print(f"the average of {num1},{num2} and {num3} is {average}")

except:
    print("check the code")
# Out:
# enetr the number 1: 10
# enter the number 2: 20
# enter the number 3: 30
# the average of 10,20 and 30 is 20.0

# %%
# if you want to show the error then use this

try:
    num1=eval(input("enetr the number 1:"))
    num2=eval(input("enter the number 2:"))
    num3=eval(input("enter the number 3:"))
    average=(num1+num2+num3)/0
    print(f"the average of {num1},{num2} and {num3} is {average}")

except Exception as e:    # this method will exact error 
    print(e)
# Out:
# enetr the number 1: 10
# enter the number 2: 20
# enter the number 3: 30
# division by zero

# %%
# WAP ask the user to enter a number and find the square of the number
try:
    num10=eval(input("enter the number"))                                        
    sq=num10*num10
    print("square of the number is",sq)
except Exception as e:
    print(e)
# Out:
# enter the number 10
# square of the number is 100

# %%
# if we get more than 1 error which error exception will show ?
#     ans:   python is a step by step execution , so it will show 1 st error

# %%
try:
    num10=eval(input("enter the number"))                                        
    sq=num10*num100
    print("square of the number is",sq)
except Exception as e:
    print("hai")
    print(e)                       #capture the error, still next is running
    print("hello")                     # running,     in this cases we will use this "try and except"
    print("how are you")

print("python")
print(1)
# Out:
# enter the number 10
# hai
# name 'num100' is not defined
# hello
# how are you
# python
# 1

# %%
try:
    num10=eval(input("enter the number"))                                        
    sq=num10*num10
    print("square of the number is",sq)
    
except Exception as e:
    print("hai")
    print(e)                       #capture the error, still next is running
    print("hello")                     # running,     in this cases we will use this "try and except"
    print("how are you")

print("python")
print(1)
# Out:
# enter the number 10
# square of the number is 100
# python
# 1

# %% [markdown]
# ### Points
# - if your code is without error, try block will execuite
# - if your code has errors, it will redirect to except block
# - what ever you written inside except block that will run
# - try and exception should together

# %%
print("************************************")
print(20*10)

try:
    num10=eval(input("enter the number"))                                        
    sq=num10*num10
    print("square of the number is",sq)

print("out")
    
except Exception as e:
    print("hai")
    print(e)                       #capture the error, still next is running
    print("hello")                     # running,     in this cases we will use this "try and except"
    print("how are you")

print("python")
print(1)
# Out:
#   Cell In[42], line 9
#     print("out")
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
print("************************************")
print(20*10)

try:
    num10=eval(input("enter the number"))                                        
    sq=num10*num10
    print("square of the number is",sq)

 print("out")
    
except Exception as e:
    print("hai")
    print(e)                       #capture the error, still next is running
    print("hello")                     # running,     in this cases we will use this "try and except"
    print("how are you")

print("python")
print(1)
# Out:
#   File <string>:9
#     print("out")
#                 ^
# IndentationError: unindent does not match any outer indentation level
