# %% [markdown]
# ### Functions

# %% [markdown]
# - it is a block of code, it can Reuse any part of code

# %%
def <function_name>():                                                                              # 16 th class
    #write your code here

# %% [markdown]
# ### Without arguments concept

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

# the output will not display untill unless you call the function

# %%
addition()
# Out:
# addition of the 10 and 20 is 30

# %%
def addition():
    print("hello")
    print("i am writing functions")

addition()


# we took addition as a function 2 times but it is execuiting 2 nd one why ?
#   because python is step by step by process . soo it will take latest update only
# Out:
# hello
# i am writing functions

# %%
# WAP ask the user enter the 3 numbers
# find the average of thode numbers
# first write normal code 
# then implement function


num1=eval(input("enter a number"))
num2=eval(input("enter a number"))
num3=eval(input("enter a number"))

average=(num1+num2+num3)/3

print(f"average of {num1} {num2} and {num3}= {average}")
# Out:
# enter a number 20
# enter a number 30
# enter a number 40
# average of 20 30 and 40= 30.0

# %%
# with function

def average_numbers():
    num1=eval(input("enter a number"))
    num2=eval(input("enter a number"))
    num3=eval(input("enter a number"))

    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

average_numbers()
# Out:
# enter a number 20
# enter a number 30
# enter a number 40
# average of 20 30 and 40= 30.0

# %% [markdown]
# ### Note:
#     We are not sure , the function is defined correct or wrong
#     untill unless we call the function

# %%
# now using try and exception method

def avg():
    
    try:
        num1=eval(input("enter a number"))
        num2=eval(input("enter a number"))
        num3=eval(input("enter a number"))
        
        average=(num1+num2+num3)/3
        
        print(f"average of {num1} {num2} and {num3}= {average}")



    except Exception as e:
        print(e)


avg()
# Out:
# enter a number sidd
# name 'sidd' is not defined

# %%
# WAP ask the user enter bill amount
#    ask the enter tip amount
#     calculate total bill


def bill():
    try:
        Bill_amount=eval(input("enter the bill amoun"))
        tip=eval(input("enter the tip mount"))
        total=Bill_amount+tip
        print("total bill is {}".format(total))

    except Exception as error:
        print(error)

bill()
# Out:
# enter the bill amoun 1000
# enter the tip mount 30
# total bill is 1030

# %%
# WAP ask user get a random number between 1 to 100
# print it is even or odd number
# Implement using function
import random
def even_odd():
    ran=random.randint(1,100)
    
    print(f" random number is {ran}")
    if ran%2==0:
        print(f" {ran} is even number")

    else:
        print(f"{ran} is odd number")

even_odd()
# Out:
#  random number is 69
# 69 is odd number

# %%
# using try and excption
import random
def even_odd1():
    try:
        ran=random.randint(1,100)
        
        print(f" random number is {ran}")
        if ran%2==0:
            print(f" {ran} is even number")
    
        else:
            print(f"{ran} is odd number")
    except Exception as error:
        print(error)

even_odd1()
# Out:
#  random number is 57
# 57 is odd number

# %%
import random
print("hello")
print("python")
def even_odd1():
    try:
        ran=random.randint(1,100)
        
        print(f" random number is {ran}")
        if ran%2==0:
            print(f" {ran} is even number")
    
        else:
            print(f"{ran} is odd number")
    except Exception as error:
        print(error)

print("calling function")
even_odd1()
print("done!")
# Out:
# hello
# python
# calling function
#  random number is 99
# 99 is odd number
# done!

# %% [markdown]
# - if you not mentioning any values inside the function bracket
# - is called as without arguments or without parameters
# - arguments or parameters

# %% [markdown]
# ### With arguments

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition()


# Q1)   inside function how many variables are there
#            3 variables are therer
# Q2)   how many users provided variables
#              2 variables

# %%
def addition(n1,n2):      # arguments
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition(100,200)   # n1=100, n2=200
# Out:
# addition of the 100 and 200 is 300

# %%
#   error1
def addition(n1,n2):
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition(200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 5
#       2     add=n1+n2
#       3     print("addition of the {} and {} is {}".format(n1,n2,add))
# ----> 5 addition(200)
#
# TypeError: addition() missing 1 required positional argument: 'n2'

# %%
#   error2
def addition():
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2     add=n1+n2
#       3     print("addition of the {} and {} is {}".format(n1,n2,add))
# ----> 5 addition()
#
# Cell In[42], line 2, in addition()
#       1 def addition():
# ----> 2     add=n1+n2
#       3     print("addition of the {} and {} is {}".format(n1,n2,add))
#
# NameError: name 'n1' is not defined

# %%
#   error3
def addition():
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition(200,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 5
#       2     add=n1+n2
#       3     print("addition of the {} and {} is {}".format(n1,n2,add))
# ----> 5 addition(200,100)
#
# TypeError: addition() takes 0 positional arguments but 2 were given

# %%
# Implement the code with arguments

def average_numbers(num1,num2, num3):
    print("num1",num1)
    print("num1",num2)
    print("num1",num3)
    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

average_numbers(20,10,30)
# Out:
# num1 20
# num1 10
# num1 30
# average of 20 10 and 30= 20.0

# %%
# WAP ask the user enter number                                                               # 17 th class
# and find the square of the number

# M-1 : write in normal ways
# M-2 : write in function with out argument
# m-3 : write in function with argument

# Normal method

NUM=eval(input("enter the number"))
square=NUM*NUM
print(f"square of the number {NUM} is {square}")
# Out:
# enter the number 10
# square of the number 10 is 100

# %%
# 2nd Method

def Square():
    NUM=eval(input("enter the number"))
    square=NUM*NUM
    print(f"square of the number {NUM} is {square}")

Square()
# Out:
# enter the number 10
# square of the number 10 is 100

# %%
# 3 rd method

def Square(NUM):
    square=NUM*NUM
    print(f"square of the number {NUM} is {square}")

Square(10)
# Out:
# square of the number 10 is 100

# %%
# WAP adk the user get one random numb 1 to 20 
# enter a number
# compare this 2 number
# if both are same : prnit("you won")
# else: print("lost")


# M1
import random
Num=random.randint(1,20)

Num1=eval(input("enter the number"))

if Num==Num1:
    print("you Won")

else:
    print("you lost")
# Out:
# enter the number 5
# you Won

# %%
# M2    without random num

import random

def Compare():
    Num=random.randint(1,20)
    
    Num1=eval(input("enter the number"))
    
    if Num==Num1:
        print("you Won")
    
    else:
        print("you lost")

Compare()
# Out:
# enter the number 5
# you lost

# %%
# M3 with arguments

import random

def Compare(Num1):
    Num=random.randint(1,20)
    
    if Num==Num1:
        print("you Won")
    
    else:
        print("you lost",Num)

Compare(Num1=eval(input("enter the number")))
# Out:
# enter the number 10
# you lost 20

# %%
import random

def Compare(Num,Num1):
    
    if Num==Num1:
        print("you Won")
    
    else:
        print("you lost",Num)


Num=random.randint(1,20)
Compare(Num,20)
# Out:
# you lost 15

# %%
import random

#=============== Function defination ================
def Compare(Num,Num1):
    
    if Num==Num1:
        print("you Won")                                  
    
    else:
        print("you lost",Num)

#============== Function Calling ====================

Compare(random.randint(1,20),eval(input("enter the number")))
# Out:
# enter the number 10
# you lost 14

# %%
# WAP ask user enter salary 
#  user to enter tax percentage
#  calculate total tax to pay

# M1

def salary():
    sal=eval(input("enter the salary"))
    tax=eval(input("enter tax percentage"))
    total_tax=(sal*tax)/100

    print("total tax paying is",total_tax)

salary()
# Out:
# enter the salary 10000
# enter tax percentage 10
# total tax paying is 1000.0

# %%
# M2

def salary(sal,tax):
   
    total_tax=(sal*tax)/100

    print("total tax paying is",total_tax)

salary(eval(input("enter the salary")),eval(input("enter tax percentage")))
# Out:
# enter the salary 10000
# enter tax percentage 10
# total tax paying is 1000.0

# %%
# default parameters

def salary(sal,tax=20):   # here fixed percentage called default parameter
   
    total_tax=(sal*tax)/100

    print("total tax paying is",total_tax)

salary(eval(input("enter the salary")))
# Out:
# enter the salary 10000
# total tax paying is 2000.0

# %%
# average of the numbers


def avg(num1,num2,num3=50):           # num3 is a default parameters
    add=(num1+num2+num3)/3
    print("average is",add)

avg(30,20)
# Out:
# average is 33.333333333333336

# %%
# error

def avg(num1,num2=50,num3):           # num3 is a default parameters
    add=(num1+num2+num3)/3
    print("average is",add)

avg(30,20)
# Out:
#   Cell In[85], line 3
#     def avg(num1,num2=50,num3):           # num3 is a default parameters
#                          ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
num1,num2=50,num3 not valid
num1=50,num2,num3 not valid
num1=50,num2=50,num3 not valid
num1,num2=50,num3=50  valid
num1,num3,num2=50

# %%
def summ(a=0,b=0):                                              # 17 th class over
    print(a*b)

summ(5,10)
# Out:
# 50

# %%
#  WAP ask the user to find the are of the circle                                       18 th class

# M-1         without arguments

import math
py=math.pi
def area():
    r=eval(input("enter the radius of the circle"))
    Area=py*r*r
    print(f"area of the circle is {Area}")

area()
# Out:
# enter the radius of the circle 5
# area of the circle is 78.53981633974483

# %%
# M-2    this is with arguments 

import math
poy=math.pi
def area(r,poy):                        
    
    Area=poy*r*r
    print(f"area of the circle is {Area}")

area(eval(input("enter the radius of the circle")),poy)
# Out:
# enter the radius of the circle 5
# area of the circle is 78.53981633974483

# %%
# m-3

import math
pii=math.pi
def area(pii,r=5):    
    
    Area=round(pii*r*r,4)
    print(f"area of the circle is {Area}")

print(pii)
area(pii)
# Out:
# 3.141592653589793
# area of the circle is 78.5398

# %%
Area           # it is showing error because your using "area" outside the function === error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Area
#
# NameError: name 'Area' is not defined

# %% [markdown]
# ### Return

# %%
######

import math
py=math.pi
def area_of_circle():
    r=eval(input("enter the radius of the circle"))
    Area=py*r*r
    print(f"area of the circle is {Area}")
    return(Area)

area_of_circle()
# Out:
# enter the radius of the circle 5
# area of the circle is 78.53981633974483
# 78.53981633974483

# %%
import math
py=math.pi
def area_of_circle():
    r=eval(input("enter the radius of the circle"))
    Area=py*r*r
    print(f"area of the circle is {Area}")
    return(Area,py)

area,py=area_of_circle()
# Out:
# enter the radius of the circle 5
# area of the circle is 78.53981633974483

# %%
# ask the use enter 3 numbers
# find the sum and average
# return the average value and sum both

def avg_summ():
    num4=eval(input("enter a number"))
    num5=eval(input("enter a number"))
    num6=eval(input("enter a number"))

    summ=num4+num5+num6
    average=summ/3
    
    print(f"average of {num4} {num5} and {num6}= {summ} and {average}")
    return("additionis",summ,"average is",average)


avg_summ()
# Out:
# enter a number 5
# enter a number 6
# enter a number 7
# average of 5 6 and 7= 18 and 6.0
# ('additionis', 18, 'average is', 6.0)

# %%
def avg_summ():
    num4=eval(input("enter a number"))
    num5=eval(input("enter a number"))
    num6=eval(input("enter a number"))

    summ=num4+num5+num6
    average=summ/3
    
    print(f"average of {num4} {num5} and {num6}= {summ} and {average}")
    return(summ,average)


add,aver=avg_summ()
# Out:
# enter a number 5
# enter a number 6
# enter a number 7
# average of 5 6 and 7= 18 and 6.0

# %%
# error showing when return is not written

def avg_summ():
    num4=eval(input("enter a number"))
    num5=eval(input("enter a number"))
    num6=eval(input("enter a number"))

    summ=num4+num5+num6
    average=summ/3
    
    print(f"average of {num4} {num5} and {num6}= {summ} and {average}")
  


add,aver=avg_summ()
# Out:
# enter a number 5
# enter a number 6
# enter a number 7
# average of 5 6 and 7= 18 and 6.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 13
#       7     average=summ/3
#       9     print(f"average of {num4} {num5} and {num6}= {summ} and {average}")
# ---> 13 add,aver=avg_summ()
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# WAP ask the user to entr 3 numbers
# find the biggest number
# return that numbers

# M-1:

def greater_number():
    number1=eval(input("enter a number"))
    number2=eval(input("enter a number"))
    number3=eval(input("enter a number"))
    
    if number1>=number2 and number1>=number3:
        print(f"biggest number is number1 {number1}")
        
    elif number2>=number1 and number2>=number3:
        print(f"biggest number is number2 {number2}")
    
    else:
        print(f"biggesr number is number3 {number3}")

greater=greater_number()
# Out:
# enter a number 5
# enter a number 7
# enter a number 8
# biggesr number is number3 8

# %%
# M-2:


def greater_number():
    number1=eval(input("enter a number"))
    number2=eval(input("enter a number"))
    number3=eval(input("enter a number"))
    
    if number1>=number2 and number1>=number3:
        print(f"biggest number is number1 {number1}")
        
        return(number1)
    elif number2>=number1 and number2>=number3:
        print(f"biggest number is number2 {number2}")
        
        return(number2)
    else:
        print(f"biggesr number is number3 {number3}")
        
        return(number3)
    

greater_number()
# Out:
# enter a number 8
# enter a number 94
# enter a number 5
# biggest number is number2 94
# 94

# %%
def add(a,b):
    return(a+b)

def mul(a,b):
    return(a*b)

def sub(a,b):
    return(a-b)

def div(a,b):
    return(a/b)

val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)

print(val_add,val_sub,val_mul,val_div)
# Out:
# 50 -10 600 0.6666666666666666

# %%
def aggri(a,b):
    return(a+b,a-b,a*b,a/b)


value=aggri(20,30)
value
# print(add,sub,mul,round(div,2))
# Out:
# (50, -10, 600, 0.6666666666666666)

# %%
def add(a,b):return(a+b)

def mul(a,b):return(a*b)

def sub(a,b):return(a-b)

def div(a,b):return(a/b)

val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)

print(val_add,val_sub,val_mul,val_div)
# Out:
# 50 -10 600 0.6666666666666666

# %% [markdown]
# - with out arguments
# - with arguments
# - Default arguments
# - return statements

# %% [markdown]
# ### Local variables & Global variables :                                            19 th class

# %%
def addition():
    n1=10                                # local variables
    n2=20
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition()
# Out:
# addition of the 10 and 20 is 30

# %% [markdown]
# **local Variables :**
#
#         - the variables provided inside the function and we can access inside function only
#
# **global variables:**
#
#         - The variables provided outside the function and we acn access everywhere in the program

# %%
# local variables 

def average_numbers():
    num1=50
    num2=10
    num3=20

    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

average_numbers()
# Out:
# average of 50 10 and 20= 26.666666666666668

# %%
# local variables

def average_numbers():
    num1=eval(input("enter a number"))
    num2=eval(input("enter a number"))
    num3=eval(input("enter a number"))

    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

average_numbers()
# Out:
# enter a number 10
# enter a number 20
# enter a number 30
# average of 10 20 and 30= 20.0

# %% [markdown]
# - If you want to use Local variables outside the function then use  "" return""
# - untill unless you return those value

# %%
n1=10
n2=20               # global variables

def addition():                  # no need to provide inside the brackets
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition()
# Out:
# addition of the 10 and 20 is 30

# %%
# global variables

num1=50
num2=10
num3=20

def average_numbers():

    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

average_numbers()
# Out:
# average of 50 10 and 20= 26.666666666666668

# %%
# global variable
def average_numbers():

    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

num1=50
num2=10                                       # we can provide like this also , 
num3=20
average_numbers()

print(num1*num2)
# Out:
# average of 50 10 and 20= 26.666666666666668
# 500

# %%
# we can also provide like this      global variables

num1=eval(input("enter a number"))
num2=eval(input("enter a number"))
num3=eval(input("enter a number"))

def average_numbers():
    

    average=(num1+num2+num3)/3
    
    print(f"average of {num1} {num2} and {num3}= {average}")

average_numbers()
# Out:
# average of 50 10 and 20= 26.666666666666668

# %%
# Out:
# enter a number 10
# enter a number 30
# enter a number 20
# average of 10 30 and 20= 20.0

# %%
# Tell the answer

n1=10
n2=20               # global variables

def addition():                  # no need to provide inside the brackets
    n1=5
    n2=6
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition()

print(n2)
# Out:
# addition of the 5 and 6 is 11
# 20

# %%
# Tell the answer

n1=10
n2=20               # global variables

def addition(n1):                  # no need to provide inside the brackets
    
    n2=6
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition(500)

print(n2)
# Out:
# addition of the 500 and 6 is 506
# 20

# %%
# Tell the answer

n1=10
n2=20               # global variables

def addition(n1=700):                  
    
    n2=300                 # local variables
    add=n1+n2
    print("addition of the {} and {} is {}".format(n1,n2,add))

addition(500)

print(n2)
# Out:
# addition of the 500 and 300 is 800
# 20

# %% [markdown]
# -  global and local variables will come only when we create a function
# -  if we not create the function then it is always ""global variables""

# %%
# global and local variables will come only when we create a function

def greater_number():
    number1=eval(input("enter a number"))
    number2=eval(input("enter a number"))
    number3=eval(input("enter a number"))
    
    if number1>=number2 and number1>=number3:
        print(f"biggest number is number1 {number1}")
        
        return(number1)
    elif number2>=number1 and number2>=number3:
        print(f"biggest number is number2 {number2}")
        
        return(number2)
    else:
        print(f"biggesr number is number3 {number3}")
        
        return(number3)
    

greater_number()
# Out:
# enter a number 10
# enter a number 20
# enter a number 4
# biggest number is number2 20
# 20

# %%
#  if we not create the function then it is always ""global variables""


number1=eval(input("enter a number"))
number2=eval(input("enter a number"))                             # see this are always global variables
number3=eval(input("enter a number"))

if number1>=number2 and number1>=number3:
    print(f"biggest number is number1 {number1}")
    
    return(number1)
elif number2>=number1 and number2>=number3:
    print(f"biggest number is number2 {number2}")
    
    return(number2)
else:
    print(f"biggesr number is number3 {number3}")
    
    return(number3)
# Out:
# enter a number 10
# enter a number 20
# enter a number 6
#   Cell In[73], line 11
#     return(number1)
#     ^
# SyntaxError: 'return' outside function

# %%
# if u want to use the local variables outside the function ,without using return Statement

for that we have to use   "" global  "" keyword

# %%
n_111=10
def updated():
    n_111=20
    n_111=n_111+100
    print("n1 value inside function is:", n_111)

updated()
print(n_111)

# without return n1, we need to get the updated value
# we need to use local variables outside the function,without return
# Out:
# n1 value inside function is: 120
# 10

# %%
# local variables can be use as a global variables by using global key word

def value1():
    global number1,number2
    number1=100
    number2=200
    print("value inside function is:", number1,number2)

value1()
print(number1,number2)
# Out:
# value inside function is: 100 200
# 100 200

# %%
n1=20
n2=30

def addition(n1):
    global n2,add
    n2=300
    add=n1+n2
    print(f"the addition of {n1} and {n2} numbers is {add}")

addition(n1)
print(n2)            # n2 value 300 , insted of 30
print(add)      # add value
# Out:
# the addition of 20 and 300 numbers is 320
# 300
# 320

# %% [markdown]
# ### Function in Function

# %%
def greet():
    print("hello")

def name():
    print("python")

greet()
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")

def name():             # 1 function
    print("python")    
    greet()              # 2nd function             , called function in function

name()
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    

def name():
    print("python")
    greet()

greet()
name()
# Out:
# hello
# python
# hello

# %%
print(3)
def fun1():
    print("hello")
    print("python")

print("10+10")
def fun2():
    print("3+5")
    print(3+5)
    fun1()
    print("good")

print(10+10)
def fun3():
    fun1()
    fun2()

fun3()
# Out:
# 3
# 10+10
# 20
# hello
# python
# 3+5
# 8
# hello
# python
# good

# %%
# create 4 funs
# def add(a+b)
#      print(a+b)
# dub
# mul
# div
#  def main():
# you need to provide some print statement
# if you want enter 1: addition operation will come
# if you want enter 2: sub
# if you want enter 3: mul
# if you want enter 4: div

# operation=input("enter a number ")
# a=eval(input())
# b=eval(input())
# if operation=="1"
#      add(a,b)
# if operation=="2"
#      sub(a,b)
# if operation=="3"
#      mul(a,b)
# if operation=="4"
#      div(a,b)




def add(a,b):
    print(a+b)

def sub(a,b):
    print(a-b)

def mul(a,b):
    print(a*b)

def div(a,b):
    print(a/b)

def main():
    print("you need to provide some print statement")
    print("""if you want enter 1: addition operation 
    if you want enter 2: sub
    if you want enter 3: mul
    if you want enter 4: div""")

    operation=eval(input("enter a number"))
    if operation==1:
        add(10,5)

    elif operation==2:
        sub(10,5)

    elif operation==3:
        mul(10,5)

    else:
        div(10,5)

main()
# Out:
# you need to provide some print statement
# if you want enter 1: addition operation
#     if you want enter 2: sub
#     if you want enter 3: mul
#     if you want enter 4: div
# enter a number 4
# 2.0

# %%
a=eval(input("enter the a value"))
b=eval(input("enter the b value"))

def add():
    print(a+b)

def sub():
    print(a-b)

def mul():
    print(a*b)

def div():
    print(a/b)

def main():
    print("you need to provide some print statement")
    print("""if you want enter 1: addition operation 
    if you want enter 2: sub
    if you want enter 3: mul
    if you want enter 4: div""")

    operation=eval(input("enter a number"))
    if operation==1:
        add()

    elif operation==2:
        sub()

    elif operation==3:
        mul()

    else:
        div()

main()
# Out:
# enter the a value 10
# enter the b value 5
# you need to provide some print statement
# if you want enter 1: addition operation
#     if you want enter 2: sub
#     if you want enter 3: mul
#     if you want enter 4: div
# enter a number 1
# 15
