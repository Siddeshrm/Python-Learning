# %% [markdown]
# ### Data types         29 th may
#
# -  integer
#       int
# -  float
#       float
# -  strings
#       str
# -  boolean
#        bool
# -  complex conjugate
#       complex

# %% [markdown]
# $integer$

# %%
number=100
number
# Out:
# 100

# %%
#type of the variable: type
type(number)
# Out:
# int

# %% [markdown]
# #different number system
#
# - decimal
# - binary
# - octa
# - hexa

# %% [markdown]
# $binary$

# %%
0b0101
# Out:
# 5

# %%
0b10101
# Out:
# 21

# %%
0b110
# Out:
# 6

# %% [markdown]
# $Octa$

# %%
0o010
# Out:
# 8

# %%
0o100
# Out:
# 64

# %%
0o123
# Out:
# 83

# %%
0o7564
# Out:
# 3956

# %%
0o001
# Out:
# 1

# %%
0o111
# Out:
# 73

# %%
0o10000
# Out:
# 4096

# %% [markdown]
# $Hexa$

# %%
0xa00
# Out:
# 2560

# %%
0x0b0
# Out:
# 176

# %%
0x00c
# Out:
# 12

# %%
0xabc
# Out:
# 2748

# %% [markdown]
# $Float$

# %%
pi=3.14
pi
# Out:
# 3.14

# %%
type(pi)
# Out:
# float

# %% [markdown]
# $e$ $representatoion$

# %%
10e3
# Out:
# 10000.0

# %%
1e-3
# Out:
# 0.001

# %%
1e3
# Out:
# 1000.0

# %% [markdown]
# $Strings$

# %%
name = "siddesh"
name
# Out:
# 'siddesh'

# %%
type(name)
# Out:
# str

# %%
name1="siddesh
 how are you ?"
# Out:
#   Cell In[42], line 1
#     name1="siddesh
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#to write multiple lines use triple quotes called DOC string 
names = """siddesh 
            dog eats meet
            cat eats rats"""
names
# Out:
# 'siddesh \n            dog eats meet\n            cat eats rats'

# %%
type(names)
# Out:
# str

# %%
# date 29 th May 
# single string
str1='siddesh'
str1
# Out:
# 'siddesh'

# %%
#double string
str2="double string"
str2
# Out:
# 'double string'

# %%
# triple string is called doc string to write multiple lines
str3= """hi 
          how are you.
          i am fine,
          what about you"""
str3
# Out:
# 'hi \n          how are you.\n          i am fine,\n          what about you'

# %% [markdown]
# **Boolean**

# %%
#if u ask question to the computer it will answer True or false 
# True =1
# False =0 
True 
False

# %%
value = False
value
type(value)
# Out:
# bool

# %%
value = True
value
type(value)
# Out:
# bool

# %%
name1 = True  # boolean
name2 = true  # both are Variables
name3 = "true" # string

# %%
name2 = true # because true is not defined, so i am not able to use that
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 name2 = true
#
# NameError: name 'true' is not defined

# %%
true =100     # 100 is saving in the variable true
name2=true    # true is saving in the variable name2
name2         # so name2 is 100
# Out:
# 100

# %%
a=100       #pyhton will consider latest value 
b=200
a=b            # a=200
b=a            # b=200 becos a value changed to 200 in above line a=b
a=500
b=a
b=900
a,b
# Out:
# (500, 900)

# %% [markdown]
# $Complex$ $Conjugate$

# %% [markdown]
# -  a+ib   or   a+jb
# -  a = real part
# -  b = imaginary part
# -  i = sqrt(-1)

# %%
num = 3+5j
num
# Out:
# (3+5j)

# %%
type(num)
# Out:
# complex

# %%
nums = 3-5j
nums
# Out:
# (3-5j)

# %%
# if we want output as real or imaginary part seperately 
3+5j
# 3 = real part
# 5 = imaginary part

# %%
dir(num)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'conjugate',
#  'imag',
#  'real']

# %%
num.imag
# Out:
# 5.0

# %%
num.real
# Out:
# 3.0

# %%
num.conjugate()   # when ever you see normal bracket () it is called fun/method
# num.real
# num.imag
# num.conjugate()
# Out:
# (3-5j)

# %%
complex(4,10)
# real = 4 imaginary = 10
# 4+10j
# Out:
# (4+10j)

# %%
complex(4,-10)
# Out:
# (4-10j)

# %%
# if not provide anything inside
# by default real =0 and imaginary =0 ANS =0j
complex()
# Out:
# 0j

# %% [markdown]
# -  when ever you see normal bracket () it is called fun/method
#
# -  inside brackets (4,5) called parameters/arguments

# %%
import random
random.randint # here no bracket so error is showing called method
# Out:
# <bound method Random.randint of <random.Random object at 0x000002014A3F2B30>>

# %%
import math
math.sin   # here also same no fun
# Out:
# <function math.sin(x, /)>

# %%
import random
random.randint() # now it is showing give arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
# which one will give answer and which one will give error
random.randint()    # error
math.sin()          # error
complex()           # 0j
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 random.randint()
#       2 math.sin()
#       3 complex()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'
