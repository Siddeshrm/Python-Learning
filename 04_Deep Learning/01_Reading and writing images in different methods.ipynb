# %% [markdown]
# ## Chapter-1 ##

# %%
import cv2

# first import the package                                                         104 th class
# for error -- install the package

# pip install opencv-python

# if install through CMD : remove ! mark
#                           pip install opencv-python

# if you install through jupyter notebook: add the ! mark and run
#                          !pip install opencv-python

# %% [markdown]
# **Method-1**
#
# - Uing openCV method
# - When you read image, it will open in new window
# - And image will display on the window
# - If you want to close the window press : 0

# %%
import os
os.getcwd()

# "./Benjamin-Franklin.jpg" # Relative path

# "C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg"  # Absollute path
# Out:
# 'C:\\DS_Py\\04_Deep Learning'

# %%
# All together in local

import cv2
image=cv2.imread("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")

# input1 = cv2.imread("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")

cv2.imshow("benjiman",image)                    # don't use directly i am show  kernal will dead
cv2.waitKey(0)                             # use this waitkey (it is in milisec) and destroyallwindows. if press 0 it willl close new window
cv2.destroyAllWindows()

# %% [markdown]
# **Method-2**
#
# - Using google colab notebook
# - Run below codes in google colab only

# %%
# ========== In google colab =================

from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread("contents/Benjamin-Franklin.jpg")
cv2_imshow(image)

# %% [markdown]
# **Method-3**
#
# - Using Pillow package

# %%
# By using pillow it will open in another window
from PIL import Image
image = Image.open("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")
image.show()   # open in new window

# %%
# By using pillow it will open in another window
from PIL import Image
image = Image.open("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")
image   # open in jupyter notebook
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=147x180>

# %% [markdown]
# **Method-4**
#
# - Open using matplotlib

# %%
# Read the image using pillow and open the image using matplotlib
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")
# open the image using matplotlib
plt.imshow(image)

# %%
# Read the image using openCV and open the image using matplotlib
import matplotlib.pyplot as plt
import cv2
image = cv2.imread("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")
# open the image using matplotlib
plt.imshow(image)

# %% [markdown]
# **Writing images**

# %%
import cv2
image=cv2.imread("C:\\DS_Py\\03_ML Python\\Benjamin-Franklin.jpg")
cv2.imwrite('output.jpg',image)
cv2.imwrite('output.png', image)
