# %% [markdown]
# **Data transformation**

# %%
# step-1                                                                 # 55 th class continue previous notebook
# Read the pacakges

import pandas as ps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Converting skewed distribution to Normal distribution
# - All maths developed by assumption as data follows Normal distribution
# - some methods are
#     - log transformation
#     - Reciprocal transformation
#     - sqrt transformation
#     - exponential transformation
#     - box-cox transformation
#     - yeo-jhanosn transformation

# %% [markdown]
# $step-2$
#
# **Read the data**

# %%
data=np.random.exponential(size=10000)

# it is like exponential distribution
# we are taking 1000 random values

# %%
plt.hist(data,bins=40,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# $Step-3$
#
# **Log transformation**
#
# - np.log represent natural logorithem
# - natural logorithem means base e
# - exponential will multiply with log base e
# - Natural logorithema will works positive data
# - log transformation will remove the skew
# - It will not convert into Normal distribution

# %%
log_data=np.log(data)
plt.hist(log_data,bins=40,label='Log transformation')
plt.legend()
plt.show()                                                    # apply natural (log base e) log, for exponential

# %%
plt.subplot(1,2,1).hist(data,bins=40)
plt.subplot(1,2,2).hist(log_data,bins=40)
plt.show()

# %%
log_data=np.log(log_data)
plt.hist(log_data,bins=40,label='Log transformation')
plt.legend()
plt.show()                                                    # apply natural (log base e) log, for exponential

# negetive values are there so we are getting run time warning
# Out:
# C:\Users\SIDDESH R M\AppData\Local\Temp\ipykernel_20040\847496691.py:1: RuntimeWarning: invalid value encountered in log
#   log_data=np.log(log_data)

# %% [markdown]
# $Step-4$
#
# **Reciprocal transformation**
#
# - Reciprcal transformation will not use full for ""value having zeros""
# - if data has zero, it will fail

# %%
rec_data=1/data
plt.hist(rec_data,bins=40,label='Reciprocal transformation')
plt.legend()
plt.show()

# %% [markdown]
# $Step-5$
#
# **Square root transformation**

# %%
sqrt_data=np.sqrt(data)
plt.hist(sqrt_data,bins=40,label='Square root Transformation')
plt.show()

# %%
#""""""""""""""""" IMPORTANT deloit interview question """""""""""""""
# distance between points
[(1,2),(6,7)]

x1,y1=(1,2)
x2,y2=(6,7)
d1=x2-x1
d2=y2-y1
data=(d1**2)+(d2**2)
D=np.sqrt(data)
D
# Out:
# np.float64(7.0710678118654755)

# %% [markdown]
# **Power Transformer**
#
# - it is in sklearn.preprocessing                   ""HW""
# - method argument
# - box-cox
# - ye-jhonson
