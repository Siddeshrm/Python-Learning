# %% [markdown]
# $Step - 1$
#
# **Import required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $Step - 2$
#
# **read the dataset**

# %%
file_path="C:\\DS_Py\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $Shape$

# %%
# dataframe name is visa_df
visa_df.shape
# Out:
# (25480, 12)

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print('the number of rows are:',visa_df.shape[0])
print('the number of columns are:',visa_df.shape[1])
# Out:
# the number of rows are: 25480
# the number of columns are: 12

# %%
# <package_name>.<method_name>()

# %%
visa_df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 visa_df.shape()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# - Function are used to call
# - Function means()
# - not callable means, remove the brackets

# %% [markdown]
# $Size$

# %%
visa_df.size

# number of rows*number of columns
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1]

# 25480*12
# Out:
# 305760

# %% [markdown]
# $Columns$

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
visa_df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')>

# %%
visa_df.columns.to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# - when it shows " not callable" , don't use bracket()
# - if output shows Bound method use "Bracket()"

# %%
dict() ======== to_dict
list() ======== to_list

# %% [markdown]
# $Dtypes$

# %%
visa_df.dtypes

# object means catogorical column
# int64 and float64 for numerical column
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa_df.dtypes.index       # left side data you will get
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.values  # if we use "brackets ()" it showing error == not callable, so not to use "()"
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
type(visa_df.dtypes.values) 

# numpy n dimensions array
# Out:
# numpy.ndarray

# %%
# important**************************************************************


dir(visa_df.dtypes)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
list1=[1,2,3]
list1

[1,2,3]+[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
np.array([1,2,3])+np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %% [markdown]
# - array[] ====> numpy
# - index[] ====> pandas index
# - pandas.datafram
# - pandas.series

# %% [markdown]
# $task-1$
#
# **seperate categorical columns, numerical column in list**

# %%
visa_df.dtypes

# to do this into list convert it into dictionary
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dict(visa_df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dict1=dict(visa_df.dtypes)
for i,j in dict1.items():
    if j=='object':
        print(i)

cat=[key for key,value in dict1.items() if value=='object']
cat
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# region_of_employment
# unit_of_wage
# full_time_position
# case_status
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# $Head$

# %%
visa_df.head()  # top 5 rows

# starting with index 0
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# $tail$

# %%
visa_df.tail()   # last 5 rows
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# $take$

# %%
list1=[100,200,300]
visa_df.take(list1)      # it will give which coulmns number u want
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
list1=[100,200,300]
visa_df.take(list1,axis=1)

# axis=1 column
# 100 200 300
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 2
#       1 list1=[100,200,300]
# ----> 2 visa_df.take(list1,axis=1)
#       4 # axis=1 column
#       5 # 100 200 300
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4155, in NDFrame.take(self, indices, axis, **kwargs)
#    4150     # We can get here with a slice via DataFrame.__getitem__
#    4151     indices = np.arange(
#    4152         indices.start, indices.stop, indices.step, dtype=np.intp
#    4153     )
# -> 4155 new_data = self._mgr.take(
#    4156     indices,
#    4157     axis=self._get_block_manager_axis(axis),
#    4158     verify=True,
#    4159 )
#    4160 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4161     self, method="take"
#    4162 )
#
# ...

# %%
visa_df.take([2,5,11],axis=1)

# if you give 12 insted of 11 == error ,becz max columns == 11
# Out:
#       education_of_employee  no_of_employees case_status
# 0               High School            14513      Denied
# 1                  Master's             2412   Certified
# 2                Bachelor's            44444      Denied
# 3                Bachelor's               98      Denied
# 4                  Master's             1082   Certified
# ...                     ...              ...         ...
# 25475            Bachelor's             2601   Certified
# 25476           High School             3274   Certified
# 25477              Master's             1121   Certified
# 25478              Master's             1918   Certified
# 25479            Bachelor's             3195   Certified
#
# [25480 rows x 3 columns]

# %%
visa_df.take([2,5,11],axis=0)
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 2   EZYV03      Asia            Bachelor's                  N
# 5   EZYV06      Asia              Master's                  Y
# 11  EZYV12      Asia           High School                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                      Y            44444         2008                 West
# 5                      N             2339         2012                South
# 11                     N             4069         2005            Northeast
#
#     prevailing_wage unit_of_wage full_time_position case_status
# 2         122996.86         Year                  Y      Denied
# 5          78252.14         Year                  Y   Certified
# 11         70813.09         Year                  Y      Denied

# %% [markdown]
# $task - 2$
#
# **I want 150 300,450 rows from 5,8,12**

# %%
visa_df.take([4,7,11],axis=1)
# Out:
#       requires_job_training region_of_employment case_status
# 0                         N                 West      Denied
# 1                         N            Northeast   Certified
# 2                         Y                 West      Denied
# 3                         N                 West      Denied
# 4                         N                South   Certified
# ...                     ...                  ...         ...
# 25475                     Y                South   Certified
# 25476                     N            Northeast   Certified
# 25477                     N                South   Certified
# 25478                     Y                 West   Certified
# 25479                     N              Midwest   Certified
#
# [25480 rows x 3 columns]

# %%
visa_df.take([4,7,11],axis=1).take([150,300,450])
# Out:
#     requires_job_training region_of_employment case_status
# 150                     N                 West      Denied
# 300                     N              Midwest   Certified
# 450                     Y                 West      Denied

# %%
visa_df.take([100:200])
# Out:
#   Cell In[31], line 1
#     visa_df.take([100:200])
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# $ iloc$ - $loc$

# %%
visa_df.iloc[<rows>,<columns>]
visa_df.iloc[start:end,start:end]

# %%
visa_df.iloc[100:150]                  # all the columns
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 100  EZYV101           Asia              Master's                  Y
# 101  EZYV102           Asia              Master's                  Y
# 102  EZYV103           Asia            Bachelor's                  Y
# 103  EZYV104           Asia             Doctorate                  Y
# 104  EZYV105           Asia              Master's                  Y
# 105  EZYV106  North America             Doctorate                  Y
# 106  EZYV107           Asia            Bachelor's                  N
# 107  EZYV108           Asia            Bachelor's                  Y
# 108  EZYV109           Asia            Bachelor's                  N
# 109  EZYV110           Asia            Bachelor's                  Y
# 110  EZYV111  North America           High School                  Y
# 111  EZYV112           Asia              Master's                  Y
# 112  EZYV113           Asia            Bachelor's                  Y
# ...

# %%
visa_df.iloc[50:55,2:6] visa_df.iloc[50:55,2:6]       # visa_df.iloc[start:end,start:end]

# 50 rows 54
# 2 to 5
# Out:
#    education_of_employee has_job_experience requires_job_training  \
# 50            Bachelor's                  N                     N
# 51              Master's                  Y                     N
# 52            Bachelor's                  N                     N
# 53           High School                  Y                     N
# 54              Master's                  Y                     N
#
#     no_of_employees
# 50              746
# 51             3129
# 52             1647
# 53             2438
# 54            11733

# %%
visa_df.iloc[[100,150,200]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 150  EZYV151      Asia            Bachelor's                  N
# 200  EZYV201      Asia             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 150                     N            50351         1975                 West
# 200                     N             3282         1979                 West
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100       28243.7900         Year                  Y   Certified
# 150         529.1105         Hour                  Y      Denied
# 200       74441.1100         Year                  Y   Certified

# %%
visa_df.iloc[[100,150,200],[5,8,11]]
# Out:
#      no_of_employees  prevailing_wage case_status
# 100             2227       28243.7900   Certified
# 150            50351         529.1105      Denied
# 200             3282       74441.1100   Certified

# %%
# 100,200,300  from only case status column

visa_df.iloc[[100,150,200] ,11]          # for large number of columns we cannot count so . if we give "case status" itS won't work


visa_df.iloc[[100,150,200] ,'case_status']  # it is easy but it will take only numbers
#  becz iloc will take only numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer._validate_tuple_indexer(self, key)
#     966 try:
# --> 967     self._validate_key(k, i)
#     968 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1615, in _iLocIndexer._validate_key(self, key, axis)
#    1614 else:
# -> 1615     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 6
#       1 # 100,200,300  from only case status column
# ...

# %%
# To avoid this drawbcak we go for ILOC

visa_df.loc[[100,150,200] ,['case_status']]
# Out:
#     case_status
# 100   Certified
# 150      Denied
# 200   Certified

# %%
rows=[100,200,300]
cols=['continent','case_status']
visa_df.loc[rows,cols]
# Out:
#     continent case_status
# 100      Asia   Certified
# 200      Asia   Certified
# 300      Asia   Certified

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# $isnull$

# %% [markdown]
# - any missing values are there in the data
# - is null you are asking question to computer:True/False
# - If any missing values are there it is True
# - If data presents/no missing values False

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# $infO$

# %%
visa_df.info()     # what task and methods we did untill here , ""info"" is every thing is in one
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# ## what we learnt
#
# - shape
# - size
# - dtypes
# - columns
# - we seperated cat and num
# - head
# - tail
# - take
# - iloc
# - loc
# - len
# - is null
# - info
# - take
# - iloc
# - loc
