# %%
###### packages ####                                                      #### 45 th class
******** EDA *******
1)  Pandas : Dataframe analysis
2)  numpy  : Numerical Python/Number python
3)  matplotlib : plot
4)  seaborn :   plot
5)  plotly  :   plot
6)  bokhe   :   plot


********** ML ********
7)   scikit-learn
********** DL ********
8)   tensorflow
9)   keras
10)  pytorch
11)  cv: computer vision
********* NLP ********
12)  NLTK
13)  scipy

# %% [markdown]
# $Step-1$
#
# **Import required pcakages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $Step-2$
#
# **Read the data**

# %% [markdown]
# $visadataset$

# %%
# file location
# file name 
# extention

file_path="C:\\DS_Py\\Visadataset.csv"

pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $Bankdata$

# %%
file_path="C:\\DS_Py\\bank.csv"
                                      # some times it include some random data sets in 1 column ,,, during that time use ""sep=';'
pd.read_csv(file_path)
# pd.read_csv(file_path,sep=';')          # ulta is comming becz dataset is correct formate
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# $Step-3$
#
# **Create a dataframe using lists**

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]

pd.DataFrame(zip(list1,list2))
# Out:
#         0   1
# 0     Ram  30
# 1  Raheem  31
# 2  Robert  32

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]
cols=['Name','Age']
names=pd.DataFrame(zip(list1,list2),columns=cols)

# %% [markdown]
# $step - 4$
#
# **How to save the dataframe in local**

# %%
# whatis your datd fram name : names
# where you want to save: "C:\\DS_Py\\"
# what name you want to provide : NAMES

names.to_csv("C:\\DS_Py\\NAMES.csv")

# %%
# our python file and data file are in the same location , no need to give full path
# if both files are in different location , we have to give full path 


# this will save in the python files
names.to_csv("NAMES.csv")

# %%
# it will not create extra column as index 

names.to_csv("NAMES1.csv",index=False)

# %% [markdown]
# $Task - 1$
#
# **Read NAMES and NAMES1**

# %%
file_name="NAMES.csv"

pd.read_csv(file_name)

# how can we avoid nunamed:0
# Out:
#    Unnamed: 0    Name  Age
# 0           0     Ram   30
# 1           1  Raheem   31
# 2           2  Robert   32

# %%
file_name="NAMES1.csv"

pd.read_csv(file_name)
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# $step - 5$
#
# **Add a new column to existing dataframe**

# %%
# What is your data frame name: names
# What is the name of the column you want add : city
# how many rows we have in original data : 3
# what is your new data = ['Hyb','chennai','Blr']

names['city']=['Hyb','chennai','Blr']
names


# no fo city should meet the == original data length==3,  if cities ==4 or ==2 it will give error
# Out:
#      Name  Age     city
# 0     Ram   30      Hyb
# 1  Raheem   31  chennai
# 2  Robert   32      Blr

# %% [markdown]
# $Step - 6$
#
# **How to Drop the column**

# %%
# Data frame name: name

# axis=1 ======== columns
# axis=0 ======== rows


# ame of the column = city 


# inplace=True: data will be overwrite

# %%
names.drop('city',axis=1,inplace=True)
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# - How to read csv data                                                                       # 46 th class
#
# - How to create the  dataframe using List
#
# - How to save in local
#
# - How to add the column
#
# - How to drop the column

# %% [markdown]
# $Dataframe-using-dictionary$

# %%
dict={'Students':['Ram','Raheem','Robert'],
     'Age':[30,31,32]}
dict
pd.DataFrame(dict)

# length of the names and age should be same
# Out:
#   Students  Age
# 0      Ram   30
# 1   Raheem   31
# 2   Robert   32

# %%
pd.DataFrame(dict,columns=['A','B']) # conclusion : it will not work
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
pd.DataFrame(dict,index=['A','B','C'])
# Out:
#     Names  Age
# A     Ram   30
# B  Raheem   31
# C  Robert   32

# %%
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32
